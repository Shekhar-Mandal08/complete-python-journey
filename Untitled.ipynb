# %%
def hello(a,b):
    return a+b
def hi(a,b):
    print(a+b)

r=hello(2,4)
print(r)
# Out:
# 6

# %%
r=hi(3,4)
print(r)
# Out:
# 7
# None

# %%
f=open("hello.txt","r")
s=f.read()
print(s)
# Out:
# first paragraph : hi
# my name is shekhar mandal
# Hello Python
# File handling

# %%
f=open("hello.txt","r")
print(f.readline())
print(f.readline())
# Out:
# first paragraph : hi
#
# my name is shekhar mandal

# %%
f=open("hello.txt","w")
f.write("helllo i overwrite all those ")
f.close()

# %%
f=open("hello.txt","r")
s=f.read()
print(s)
# Out:
# helllo i overwrite all those

# %%
with open("hello.txt","r")as f:
    print(f.read())
# Out:
# helllo i overwrite all those dfjfdjfhjdhfjdgfdhjf

# %%
with open("hello.txt","a+")as f:
    print(f.write("add this of "\n" hello"))
    print(f.read())
# Out:
#   Cell In[20], line 2
#     print(f.write("add this of "/n" hello"))
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
